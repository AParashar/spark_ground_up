# %%
from pyspark.sql import SparkSession
import getpass
username = getpass.getuser()

spark = SparkSession. \
builder. \
config('spark.ui.port','0'). \
config("spark.sql.warehouse.dir", f"/user/{username}/warehouse"). \
enableHiveSupport(). \
master('yarn'). \
getOrCreate()

# %%
sc = spark.sparkContext

# %%
covid_cases_rdd = sc.textFile("data/datasets/covid19/cases/covid_dataset_cases.csv")
covid_states_rdd = sc.textFile("data/datasets/covid19/states/covid_dataset_states.csv")

# %% [markdown]
# ## 2. Total count of people in ICU currently

# %%
# inIcuCurrently
covid_rdd_map = covid_cases_rdd.map(lambda x: int(x.split(",")[7]))

# %%
covid_rdd_map.reduce(lambda x,y: x+y)
# Out:
# 1344

# %%
spark.stop()
