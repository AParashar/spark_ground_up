# %%
from pyspark.sql import SparkSession
import getpass
username = getpass.getuser()

spark = SparkSession. \
builder. \
config('spark.ui.port','0'). \
config("spark.sql.warehouse.dir", f"/user/{username}/warehouse"). \
enableHiveSupport(). \
master('yarn'). \
getOrCreate()

# %%
orders_text_df = spark.read.text("data/retail_db_orders_part-00000")

# %%
orders_text_df.printSchema()
# Out:
# root
#  |-- value: string (nullable = true)

# %%
orders_text_df.columns
# Out:
# ['value']

# %%
orders_text_df.schema
# Out:
# StructType(List(StructField(value,StringType,true)))

# %%
orders_text_df.show()
# Out:
# +--------------------+
# |               value|
# +--------------------+
# |1,2013-07-25 00:0...|
# |2,2013-07-25 00:0...|
# |3,2013-07-25 00:0...|
# |4,2013-07-25 00:0...|
# |5,2013-07-25 00:0...|
# |6,2013-07-25 00:0...|
# |7,2013-07-25 00:0...|
# |8,2013-07-25 00:0...|
# |9,2013-07-25 00:0...|
# |10,2013-07-25 00:...|
# |11,2013-07-25 00:...|
# |12,2013-07-25 00:...|
# |13,2013-07-25 00:...|
# |14,2013-07-25 00:...|
# |15,2013-07-25 00:...|
# |16,2013-07-25 00:...|
# |17,2013-07-25 00:...|
# |18,2013-07-25 00:...|
# |19,2013-07-25 00:...|
# |20,2013-07-25 00:...|
# +--------------------+
# only showing top 20 rows

# %%
spark_csv_df = spark.read.csv("data/retail_db_orders_part-00000")

# %%
spark_csv_df.show()
# Out:
# +---+--------------------+-----+---------------+
# |_c0|                 _c1|  _c2|            _c3|
# +---+--------------------+-----+---------------+
# |  1|2013-07-25 00:00:...|11599|         CLOSED|
# |  2|2013-07-25 00:00:...|  256|PENDING_PAYMENT|
# |  3|2013-07-25 00:00:...|12111|       COMPLETE|
# |  4|2013-07-25 00:00:...| 8827|         CLOSED|
# |  5|2013-07-25 00:00:...|11318|       COMPLETE|
# |  6|2013-07-25 00:00:...| 7130|       COMPLETE|
# |  7|2013-07-25 00:00:...| 4530|       COMPLETE|
# |  8|2013-07-25 00:00:...| 2911|     PROCESSING|
# |  9|2013-07-25 00:00:...| 5657|PENDING_PAYMENT|
# | 10|2013-07-25 00:00:...| 5648|PENDING_PAYMENT|
# | 11|2013-07-25 00:00:...|  918| PAYMENT_REVIEW|
# | 12|2013-07-25 00:00:...| 1837|         CLOSED|
# | 13|2013-07-25 00:00:...| 9149|PENDING_PAYMENT|
# | 14|2013-07-25 00:00:...| 9842|     PROCESSING|
# | 15|2013-07-25 00:00:...| 2568|       COMPLETE|
# | 16|2013-07-25 00:00:...| 7276|PENDING_PAYMENT|
# ...

# %%
spark_csv_alt_df = spark.read.format('csv').load('data/retail_db_orders_part-00000')

# %%
spark_csv_alt_df.show()
# Out:
# +---+--------------------+-----+---------------+
# |_c0|                 _c1|  _c2|            _c3|
# +---+--------------------+-----+---------------+
# |  1|2013-07-25 00:00:...|11599|         CLOSED|
# |  2|2013-07-25 00:00:...|  256|PENDING_PAYMENT|
# |  3|2013-07-25 00:00:...|12111|       COMPLETE|
# |  4|2013-07-25 00:00:...| 8827|         CLOSED|
# |  5|2013-07-25 00:00:...|11318|       COMPLETE|
# |  6|2013-07-25 00:00:...| 7130|       COMPLETE|
# |  7|2013-07-25 00:00:...| 4530|       COMPLETE|
# |  8|2013-07-25 00:00:...| 2911|     PROCESSING|
# |  9|2013-07-25 00:00:...| 5657|PENDING_PAYMENT|
# | 10|2013-07-25 00:00:...| 5648|PENDING_PAYMENT|
# | 11|2013-07-25 00:00:...|  918| PAYMENT_REVIEW|
# | 12|2013-07-25 00:00:...| 1837|         CLOSED|
# | 13|2013-07-25 00:00:...| 9149|PENDING_PAYMENT|
# | 14|2013-07-25 00:00:...| 9842|     PROCESSING|
# | 15|2013-07-25 00:00:...| 2568|       COMPLETE|
# | 16|2013-07-25 00:00:...| 7276|PENDING_PAYMENT|
# ...

# %%
spark_schema_df = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load('data/retail_db_orders_part-00000')

# %%
spark_schema_df.show()
# Out:
# +---+---------------------+-----+---------------+
# |  1|2013-07-25 00:00:00.0|11599|         CLOSED|
# +---+---------------------+-----+---------------+
# |  2| 2013-07-25 00:00:...|  256|PENDING_PAYMENT|
# |  3| 2013-07-25 00:00:...|12111|       COMPLETE|
# |  4| 2013-07-25 00:00:...| 8827|         CLOSED|
# |  5| 2013-07-25 00:00:...|11318|       COMPLETE|
# |  6| 2013-07-25 00:00:...| 7130|       COMPLETE|
# |  7| 2013-07-25 00:00:...| 4530|       COMPLETE|
# |  8| 2013-07-25 00:00:...| 2911|     PROCESSING|
# |  9| 2013-07-25 00:00:...| 5657|PENDING_PAYMENT|
# | 10| 2013-07-25 00:00:...| 5648|PENDING_PAYMENT|
# | 11| 2013-07-25 00:00:...|  918| PAYMENT_REVIEW|
# | 12| 2013-07-25 00:00:...| 1837|         CLOSED|
# | 13| 2013-07-25 00:00:...| 9149|PENDING_PAYMENT|
# | 14| 2013-07-25 00:00:...| 9842|     PROCESSING|
# | 15| 2013-07-25 00:00:...| 2568|       COMPLETE|
# | 16| 2013-07-25 00:00:...| 7276|PENDING_PAYMENT|
# | 17| 2013-07-25 00:00:...| 2667|       COMPLETE|
# ...

# %%
spark_schema_df.schema
# Out:
# StructType(List(StructField(1,IntegerType,true),StructField(2013-07-25 00:00:00.0,StringType,true),StructField(11599,IntegerType,true),StructField(CLOSED,StringType,true)))

# %%
new_columns = ['order_id', 'order_date', 'order_customer_id', 'order_status']

# %%
spark_schema_header_df = spark_schema_df.toDF(*new_columns)

# %%
spark_schema_header_df.show()
# Out:
# +--------+--------------------+-----------------+---------------+
# |order_id|          order_date|order_customer_id|   order_status|
# +--------+--------------------+-----------------+---------------+
# |       2|2013-07-25 00:00:...|              256|PENDING_PAYMENT|
# |       3|2013-07-25 00:00:...|            12111|       COMPLETE|
# |       4|2013-07-25 00:00:...|             8827|         CLOSED|
# |       5|2013-07-25 00:00:...|            11318|       COMPLETE|
# |       6|2013-07-25 00:00:...|             7130|       COMPLETE|
# |       7|2013-07-25 00:00:...|             4530|       COMPLETE|
# |       8|2013-07-25 00:00:...|             2911|     PROCESSING|
# |       9|2013-07-25 00:00:...|             5657|PENDING_PAYMENT|
# |      10|2013-07-25 00:00:...|             5648|PENDING_PAYMENT|
# |      11|2013-07-25 00:00:...|              918| PAYMENT_REVIEW|
# |      12|2013-07-25 00:00:...|             1837|         CLOSED|
# ...

# %%
spark_schema_header_df.printSchema()
# Out:
# root
#  |-- order_id: integer (nullable = true)
#  |-- order_date: string (nullable = true)
#  |-- order_customer_id: integer (nullable = true)
#  |-- order_status: string (nullable = true)

# %%
spark_schema_header_df.columns
# Out:
# ['order_id', 'order_date', 'order_customer_id', 'order_status']

# %%
spark_schema_header_df.dtypes
# Out:
# [('order_id', 'int'),
#  ('order_date', 'string'),
#  ('order_customer_id', 'int'),
#  ('order_status', 'string')]

# %%
spark_schema_header_df.schema
# Out:
# StructType(List(StructField(order_id,IntegerType,true),StructField(order_date,StringType,true),StructField(order_customer_id,IntegerType,true),StructField(order_status,StringType,true)))

# %%
spark_df = spark_schema_header_df.withColumnRenamed('order_customer_id', 'customer_id')

# %%
spark_df.show()
# Out:
# +--------+--------------------+-----------+---------------+
# |order_id|          order_date|customer_id|   order_status|
# +--------+--------------------+-----------+---------------+
# |       2|2013-07-25 00:00:...|        256|PENDING_PAYMENT|
# |       3|2013-07-25 00:00:...|      12111|       COMPLETE|
# |       4|2013-07-25 00:00:...|       8827|         CLOSED|
# |       5|2013-07-25 00:00:...|      11318|       COMPLETE|
# |       6|2013-07-25 00:00:...|       7130|       COMPLETE|
# |       7|2013-07-25 00:00:...|       4530|       COMPLETE|
# |       8|2013-07-25 00:00:...|       2911|     PROCESSING|
# |       9|2013-07-25 00:00:...|       5657|PENDING_PAYMENT|
# |      10|2013-07-25 00:00:...|       5648|PENDING_PAYMENT|
# |      11|2013-07-25 00:00:...|        918| PAYMENT_REVIEW|
# |      12|2013-07-25 00:00:...|       1837|         CLOSED|
# |      13|2013-07-25 00:00:...|       9149|PENDING_PAYMENT|
# |      14|2013-07-25 00:00:...|       9842|     PROCESSING|
# ...

# %%
from pyspark.sql.functions import *
spark_df_new = spark_df.withColumn('order_date_dtype', to_timestamp('order_date'))

# %%
spark_df_new.show()
# Out:
# +--------+--------------------+-----------+---------------+-------------------+
# |order_id|          order_date|customer_id|   order_status|   order_date_dtype|
# +--------+--------------------+-----------+---------------+-------------------+
# |       2|2013-07-25 00:00:...|        256|PENDING_PAYMENT|2013-07-25 00:00:00|
# |       3|2013-07-25 00:00:...|      12111|       COMPLETE|2013-07-25 00:00:00|
# |       4|2013-07-25 00:00:...|       8827|         CLOSED|2013-07-25 00:00:00|
# |       5|2013-07-25 00:00:...|      11318|       COMPLETE|2013-07-25 00:00:00|
# |       6|2013-07-25 00:00:...|       7130|       COMPLETE|2013-07-25 00:00:00|
# |       7|2013-07-25 00:00:...|       4530|       COMPLETE|2013-07-25 00:00:00|
# |       8|2013-07-25 00:00:...|       2911|     PROCESSING|2013-07-25 00:00:00|
# |       9|2013-07-25 00:00:...|       5657|PENDING_PAYMENT|2013-07-25 00:00:00|
# |      10|2013-07-25 00:00:...|       5648|PENDING_PAYMENT|2013-07-25 00:00:00|
# ...

# %%
spark_df_new.printSchema()
# Out:
# root
#  |-- order_id: integer (nullable = true)
#  |-- order_date: string (nullable = true)
#  |-- customer_id: integer (nullable = true)
#  |-- order_status: string (nullable = true)
#  |-- order_date_dtype: timestamp (nullable = true)

# %%
spark_df_new.select('order_id', 'order_date_dtype', 'customer_id', 'order_status')
# Out:
# +--------+-------------------+-----------+---------------+
# |order_id|   order_date_dtype|customer_id|   order_status|
# +--------+-------------------+-----------+---------------+
# |       2|2013-07-25 00:00:00|        256|PENDING_PAYMENT|
# |       3|2013-07-25 00:00:00|      12111|       COMPLETE|
# |       4|2013-07-25 00:00:00|       8827|         CLOSED|
# |       5|2013-07-25 00:00:00|      11318|       COMPLETE|
# |       6|2013-07-25 00:00:00|       7130|       COMPLETE|
# |       7|2013-07-25 00:00:00|       4530|       COMPLETE|
# |       8|2013-07-25 00:00:00|       2911|     PROCESSING|
# |       9|2013-07-25 00:00:00|       5657|PENDING_PAYMENT|
# |      10|2013-07-25 00:00:00|       5648|PENDING_PAYMENT|
# |      11|2013-07-25 00:00:00|        918| PAYMENT_REVIEW|
# |      12|2013-07-25 00:00:00|       1837|         CLOSED|
# |      13|2013-07-25 00:00:00|       9149|PENDING_PAYMENT|
# |      14|2013-07-25 00:00:00|       9842|     PROCESSING|
# ...

# %%
df_final = spark_df_new.select('order_id', 'order_date_dtype', 'customer_id', 'order_status')

# %%
df_final.show()
# Out:
# +--------+-------------------+-----------+---------------+
# |order_id|   order_date_dtype|customer_id|   order_status|
# +--------+-------------------+-----------+---------------+
# |       2|2013-07-25 00:00:00|        256|PENDING_PAYMENT|
# |       3|2013-07-25 00:00:00|      12111|       COMPLETE|
# |       4|2013-07-25 00:00:00|       8827|         CLOSED|
# |       5|2013-07-25 00:00:00|      11318|       COMPLETE|
# |       6|2013-07-25 00:00:00|       7130|       COMPLETE|
# |       7|2013-07-25 00:00:00|       4530|       COMPLETE|
# |       8|2013-07-25 00:00:00|       2911|     PROCESSING|
# |       9|2013-07-25 00:00:00|       5657|PENDING_PAYMENT|
# |      10|2013-07-25 00:00:00|       5648|PENDING_PAYMENT|
# |      11|2013-07-25 00:00:00|        918| PAYMENT_REVIEW|
# |      12|2013-07-25 00:00:00|       1837|         CLOSED|
# |      13|2013-07-25 00:00:00|       9149|PENDING_PAYMENT|
# |      14|2013-07-25 00:00:00|       9842|     PROCESSING|
# ...

# %%
df_final.printSchema()
# Out:
# root
#  |-- order_id: integer (nullable = true)
#  |-- order_date_dtype: timestamp (nullable = true)
#  |-- customer_id: integer (nullable = true)
#  |-- order_status: string (nullable = true)

# %%
df_final.columns
# Out:
# ['order_id', 'order_date_dtype', 'customer_id', 'order_status']

# %%
df_final.dtypes
# Out:
# [('order_id', 'int'),
#  ('order_date_dtype', 'timestamp'),
#  ('customer_id', 'int'),
#  ('order_status', 'string')]

# %%
df_final.schema
# Out:
# StructType(List(StructField(order_id,IntegerType,true),StructField(order_date_dtype,TimestampType,true),StructField(customer_id,IntegerType,true),StructField(order_status,StringType,true)))

# %%
display(df_final)
# Out:
# +--------+-------------------+-----------+---------------+
# |order_id|   order_date_dtype|customer_id|   order_status|
# +--------+-------------------+-----------+---------------+
# |       2|2013-07-25 00:00:00|        256|PENDING_PAYMENT|
# |       3|2013-07-25 00:00:00|      12111|       COMPLETE|
# |       4|2013-07-25 00:00:00|       8827|         CLOSED|
# |       5|2013-07-25 00:00:00|      11318|       COMPLETE|
# |       6|2013-07-25 00:00:00|       7130|       COMPLETE|
# |       7|2013-07-25 00:00:00|       4530|       COMPLETE|
# |       8|2013-07-25 00:00:00|       2911|     PROCESSING|
# |       9|2013-07-25 00:00:00|       5657|PENDING_PAYMENT|
# |      10|2013-07-25 00:00:00|       5648|PENDING_PAYMENT|
# |      11|2013-07-25 00:00:00|        918| PAYMENT_REVIEW|
# |      12|2013-07-25 00:00:00|       1837|         CLOSED|
# |      13|2013-07-25 00:00:00|       9149|PENDING_PAYMENT|
# |      14|2013-07-25 00:00:00|       9842|     PROCESSING|
# ...

# %%
df_final.createOrReplaceTempView("orders_wh")

# %%
spark.sql("create database if not exists eComm")
# Out:
# ++
# ||
# ++
# ++

# %%
spark.sql("use eComm")
# Out:
# ++
# ||
# ++
# ++

# %%
spark.sql("show tables")
# Out:
# +--------+---------+-----------+
# |database|tableName|isTemporary|
# +--------+---------+-----------+
# |   ecomm|orders_wh|      false|
# |        |orders_wh|       true|
# +--------+---------+-----------+

# %% [markdown]
# ### Managed Table

# %%
spark.sql("create table orders_wh_csv using parquet as select * from orders_wh")
# Out:
# ++
# ||
# ++
# ++

# %%
spark.sql("select * from orders_wh limit 5")
# Out:
# +--------+-------------------+-----------+---------------+
# |order_id|   order_date_dtype|customer_id|   order_status|
# +--------+-------------------+-----------+---------------+
# |       2|2013-07-25 00:00:00|        256|PENDING_PAYMENT|
# |       3|2013-07-25 00:00:00|      12111|       COMPLETE|
# |       4|2013-07-25 00:00:00|       8827|         CLOSED|
# |       5|2013-07-25 00:00:00|      11318|       COMPLETE|
# |       6|2013-07-25 00:00:00|       7130|       COMPLETE|
# +--------+-------------------+-----------+---------------+

# %%
spark.sql("show tables")
# Out:
# +--------+-------------+-----------+
# |database|    tableName|isTemporary|
# +--------+-------------+-----------+
# |   ecomm|    orders_wh|      false|
# |   ecomm|orders_wh_csv|      false|
# |        |    orders_wh|       true|
# +--------+-------------+-----------+

# %%
spark.sql("describe extended orders_wh").show()
# Out:
# +----------------+---------+-------+
# |        col_name|data_type|comment|
# +----------------+---------+-------+
# |        order_id|      int|   null|
# |order_date_dtype|timestamp|   null|
# |     customer_id|      int|   null|
# |    order_status|   string|   null|
# +----------------+---------+-------+

# %%
spark.sql("truncate table orders_wh_csv")
# Out:
# ++
# ||
# ++
# ++

# %%
spark.sql("show tables")
# Out:
# +--------+-------------+-----------+
# |database|    tableName|isTemporary|
# +--------+-------------+-----------+
# |   ecomm|    orders_wh|      false|
# |   ecomm|orders_wh_csv|      false|
# |        |    orders_wh|       true|
# +--------+-------------+-----------+

# %%
spark.sql("select * from orders_wh_csv limit 5")
# Out:
# +--------+----------------+-----------+------------+
# |order_id|order_date_dtype|customer_id|order_status|
# +--------+----------------+-----------+------------+
# +--------+----------------+-----------+------------+

# %% [markdown]
# ### External Table

# %%
spark.sql("create table if not exists ecomm.orders_xternal using csv location './data'")
# Note: Here I had provided ./data path which is a in linux file system not HDFS. The path should be on the HDFS file system 
# (HDFS: this is the warehouse used in this particular scenario)
# Out:
# ++
# ||
# ++
# ++

# %%
spark.sql("show tables")
# Out:
# +--------+--------------+-----------+
# |database|     tableName|isTemporary|
# +--------+--------------+-----------+
# |   ecomm|     orders_wh|      false|
# |   ecomm| orders_wh_csv|      false|
# |   ecomm|orders_xternal|      false|
# |        |     orders_wh|       true|
# +--------+--------------+-----------+

# %%
spark.sql("describe extended ecomm.orders_xternal").show(truncate=False)
# Out:
# +----------------------------+------------------------------------------------------------------------------+-------+
# |col_name                    |data_type                                                                     |comment|
# +----------------------------+------------------------------------------------------------------------------+-------+
# |order_id                    |int                                                                           |null   |
# |order_date_dtype            |timestamp                                                                     |null   |
# |customer_id                 |int                                                                           |null   |
# |order_status                |string                                                                        |null   |
# |                            |                                                                              |       |
# ...

# %%
spark.sql("create table if not exists ecomm.orders_xternal2 using csv location './datasets/retail_db_orders_part-00000'")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-65-f44ddd889311> in <module>
# ----> 1 spark.sql("create table if not exists ecomm.orders_xternal2 using csv location './datasets/retail_db_orders_part-00000'")
#
# /opt/spark-3.1.2-bin-hadoop3.2/python/pyspark/sql/session.py in sql(self, sqlQuery)
#     721         [Row(f1=1, f2='row1'), Row(f1=2, f2='row2'), Row(f1=3, f2='row3')]
#     722         """
# --> 723         return DataFrame(self._jsparkSession.sql(sqlQuery), self._wrapped)
#     724
#     725     def table(self, tableName):
#
# /opt/spark-3.1.2-bin-hadoop3.2/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1303         answer = self.gateway_client.send_command(command)
#    1304         return_value = get_return_value(
# -> 1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
# ...

# %%
spark.sql("create table if not exists ecomm.orders_xternal1 (order_id int, order_date timestamp, customer_id int, order_status string) using csv location './datasets/retail_db_orders_part-00000'")

# %%
spark.sql("show tables")
# Out:
# +--------+---------------+-----------+
# |database|      tableName|isTemporary|
# +--------+---------------+-----------+
# |   ecomm|      orders_wh|      false|
# |   ecomm|  orders_wh_csv|      false|
# |   ecomm| orders_xternal|      false|
# |   ecomm|orders_xternal1|      false|
# |        |      orders_wh|       true|
# +--------+---------------+-----------+

# %%
spark.sql("describe extended ecomm.orders_xternal1")
# Out:
# +--------------------+--------------------+-------+
# |            col_name|           data_type|comment|
# +--------------------+--------------------+-------+
# |            order_id|                 int|   null|
# |          order_date|           timestamp|   null|
# |         customer_id|                 int|   null|
# |        order_status|              string|   null|
# |                    |                    |       |
# |# Detailed Table ...|                    |       |
# |            Database|               ecomm|       |
# |               Table|     orders_xternal1|       |
# |               Owner|           itv025320|       |
# |        Created Time|Thu Mar 26 06:55:...|       |
# |         Last Access|             UNKNOWN|       |
# |          Created By|         Spark 3.1.2|       |
# |                Type|            EXTERNAL|       |
# |            Provider|                 csv|       |
# |            Location|hdfs://m01.itvers...|       |
# ...

# %%
spark.sql("truncate table ecomm.orders_xternal1")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-66-a946c8fcfc1d> in <module>
# ----> 1 spark.sql("truncate table ecomm.orders_xternal1")
#
# /opt/spark-3.1.2-bin-hadoop3.2/python/pyspark/sql/session.py in sql(self, sqlQuery)
#     721         [Row(f1=1, f2='row1'), Row(f1=2, f2='row2'), Row(f1=3, f2='row3')]
#     722         """
# --> 723         return DataFrame(self._jsparkSession.sql(sqlQuery), self._wrapped)
#     724
#     725     def table(self, tableName):
#
# /opt/spark-3.1.2-bin-hadoop3.2/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1303         answer = self.gateway_client.send_command(command)
#    1304         return_value = get_return_value(
# -> 1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#    1307         for temp_arg in temp_args:
#
# ...

# %%
spark.sql("insert into table ecomm.orders_xternal1 values (126434, TIMESTAMP '2026-03-26 16:40:00', 894564248, 'COMPLETE')");
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-70-cf6859d3535e> in <module>
# ----> 1 spark.sql("insert into table ecomm.orders_xternal1 values (126434, TIMESTAMP '2026-03-26 16:40:00', 894564248, 'COMPLETE')")
#
# /opt/spark-3.1.2-bin-hadoop3.2/python/pyspark/sql/session.py in sql(self, sqlQuery)
#     721         [Row(f1=1, f2='row1'), Row(f1=2, f2='row2'), Row(f1=3, f2='row3')]
#     722         """
# --> 723         return DataFrame(self._jsparkSession.sql(sqlQuery), self._wrapped)
#     724
#     725     def table(self, tableName):
#
# /opt/spark-3.1.2-bin-hadoop3.2/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1303         answer = self.gateway_client.send_command(command)
#    1304         return_value = get_return_value(
# -> 1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
# ...

# %%
spark.sql("insert into ecomm.orders_xternal1 values (126434, CAST('2026-03-26 16:40:00' AS TIMESTAMP), 894564248, 'COMPLETE')");
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-74-d48c5321b1b8> in <module>
# ----> 1 spark.sql("insert into ecomm.orders_xternal1 values (126434, CAST('2026-03-26 16:40:00' AS TIMESTAMP), 894564248, 'COMPLETE')");
#
# /opt/spark-3.1.2-bin-hadoop3.2/python/pyspark/sql/session.py in sql(self, sqlQuery)
#     721         [Row(f1=1, f2='row1'), Row(f1=2, f2='row2'), Row(f1=3, f2='row3')]
#     722         """
# --> 723         return DataFrame(self._jsparkSession.sql(sqlQuery), self._wrapped)
#     724
#     725     def table(self, tableName):
#
# /opt/spark-3.1.2-bin-hadoop3.2/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1303         answer = self.gateway_client.send_command(command)
#    1304         return_value = get_return_value(
# -> 1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
# ...

# %%
spark.sql("insert into ecomm.orders_xternal1 values (126434, CURRENT_TIMESTAMP(), 894564248, 'COMPLETE')");
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-75-e02de073db55> in <module>
# ----> 1 spark.sql("insert into ecomm.orders_xternal1 values (126434, CURRENT_TIMESTAMP(), 894564248, 'COMPLETE')");
#
# /opt/spark-3.1.2-bin-hadoop3.2/python/pyspark/sql/session.py in sql(self, sqlQuery)
#     721         [Row(f1=1, f2='row1'), Row(f1=2, f2='row2'), Row(f1=3, f2='row3')]
#     722         """
# --> 723         return DataFrame(self._jsparkSession.sql(sqlQuery), self._wrapped)
#     724
#     725     def table(self, tableName):
#
# /opt/spark-3.1.2-bin-hadoop3.2/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1303         answer = self.gateway_client.send_command(command)
#    1304         return_value = get_return_value(
# -> 1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
# ...

# %%
spark.sql("describe ecomm.orders_xternal1")
# Out:
# +------------+---------+-------+
# |    col_name|data_type|comment|
# +------------+---------+-------+
# |    order_id|      int|   null|
# |  order_date|timestamp|   null|
# | customer_id|      int|   null|
# |order_status|   string|   null|
# +------------+---------+-------+

# %%
spark.sql("describe extended ecomm.orders_xternal1").show(truncate=False)
# Out:
# +----------------------------+----------------------------------------------------------------------------------------------------+-------+
# |col_name                    |data_type                                                                                           |comment|
# +----------------------------+----------------------------------------------------------------------------------------------------+-------+
# |order_id                    |int                                                                                                 |null   |
# |order_date                  |timestamp                                                                                           |null   |
# |customer_id                 |int                                                                                                 |null   |
# |order_status                |string                                                                                              |null   |
# ...

# %% [markdown]
# ### Getting this error persistently "Py4JJavaError: An error occurred while calling o45.sql. : java.util.NoSuchElementException: None.get"
#
# #### because the location in the hdfs is missing. While creating the external table in the command:
# spark.sql("create table if not exists ecomm.orders_xternal1 (order_id int, order_date timestamp, customer_id int, order_status string) using csv location './datasets/retail_db_orders_part-00000'")
#
# the location is './datasets/retail_db_orders_part-00000' which is local file system on the server and not HDFS. So while inserting data this location is missing in HDFS as shown below. So getting error.
# ```
# [itv025320@g02 ~]$ hdfs dfs -ls -h ./warehouse/ecomm.db
# Found 3 items
# drwxr-xr-x   - itv025320 supergroup          0 2026-03-26 06:16 warehouse/ecomm.db/orders_wh
# drwxr-xr-x   - itv025320 supergroup          0 2026-03-26 06:31 warehouse/ecomm.db/orders_wh_csv
# drwxr-xr-x   - itv025320 supergroup          0 2026-03-26 06:36 warehouse/ecomm.db/orders_xternal
# ```

# %% [markdown]
# ### While creating the external table the location I shuld have given be that present in the HDFS because insert don't find the location to write to in HDFS

# %%
spark.stop()
